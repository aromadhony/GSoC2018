# %% [markdown]
# The following code is a simple program to get category classes on OpenFoodFacts data. I use the first 10K records from https://world.openfoodfacts.org/data, and select the records with non-empty category fields (field/attribute index = 14). I employ the SVClassifier from scikit-learn to perform the classification. The attribute used for classification is ingredients (field/attribute index = 34).

# %% [markdown]
# Import the packages

# %%
import io
import string
import re
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import average_precision_score

# %% [markdown]
# Category index lookup function

# %%
def get_cat_idx(cat, cat_text):
    cat_idx = -1
    stop = False
    i = 0
    while i<len(cat) and not stop:
        if cat[i]==cat_text:
            cat_idx = i
            stop = True 
        i = i + 1        
    return cat_idx

# %% [markdown]
# Read the dataset file

# %%
categories = []
ingredients = []
food_cat = []

with open('SmallFile10K.txt') as f:
    f.readline()
    content = [x.strip('\n') for x in f.readlines()]
    for content_line in content:
        content_line_split = content_line.split('\t')
        if content_line_split[34] != '' and content_line_split[14] != '':
            cat_line = content_line_split[14].split(',')
            ing = re.sub(r'[^\w\s]','',content_line_split[34]) # remove the punctuation marks in ingredients text            
            ingredients.append(ing)
            curr_cat = []
            for cat_item in cat_line:                
                if cat_item not in categories:
                    categories.append(cat_item)
                curr_cat.append(get_cat_idx(categories, cat_item))
            food_cat.append(curr_cat)

# %% [markdown]
# Set the training and test dataset

# %%
X = np.array(ingredients)
mlb = MultiLabelBinarizer() 
Y = mlb.fit_transform(food_cat) # transform the category class to binary representation

# Split into training and test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2,
                                                    random_state=30)

# %% [markdown]
# Classify

# %%
classifier = Pipeline([
    ('vectorizer', CountVectorizer()),('tfidf', TfidfTransformer()),
    ('clf', OneVsRestClassifier(LinearSVC()))])
classifier.fit(X_train, Y_train)
predicted = classifier.predict(X_test)
# Out:
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 4 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 9 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 12 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 28 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 30 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 88 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 136 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 137 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 138 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 139 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 147 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 148 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 149 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 174 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 177 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 182 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 198 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 208 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 209 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 221 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 236 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 239 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 247 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 248 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 249 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 269 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 307 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 327 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 339 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 340 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 349 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 351 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 371 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 377 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 395 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 396 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 419 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 420 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 421 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 432 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 444 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 445 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 470 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 479 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 490 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 507 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 508 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 511 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 530 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 531 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 532 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 533 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 546 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 573 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 589 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 590 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 591 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 592 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 597 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 598 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 599 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 600 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 602 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 613 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 614 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 635 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 652 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 661 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 662 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 663 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 679 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 680 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 681 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 682 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 683 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 694 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 706 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 707 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 728 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 729 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 730 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 742 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 743 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 762 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 763 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 764 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 771 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 774 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 778 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 782 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 785 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 786 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 788 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 789 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 797 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 800 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 803 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 809 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 815 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 818 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 832 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 843 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 858 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 859 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 864 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 874 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 875 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 881 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 882 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 885 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 893 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 902 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 903 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 904 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 925 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 926 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 927 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 928 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 929 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 930 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 931 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 941 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 942 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 955 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 977 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 982 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 983 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 984 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 992 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 997 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1019 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1022 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1036 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1037 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1051 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1052 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1053 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1071 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1072 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1073 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1074 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1075 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1088 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1091 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1095 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1097 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1098 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1099 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1106 is present in all training examples.
#   str(classes[c]))
# D:\anaconda\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 1113 is present in all training examples.
#   str(classes[c]))

# %% [markdown]
# See the results

# %%
for item, labels, true_labels in zip(X_test, predicted, Y_test):
    print('item: '+item)
    for label_elmt in range(0, len(labels)):
        if labels[label_elmt]==1:
            print('label: '+str(label_elmt)+','+categories[label_elmt])
    for true_label_elmt in range(0, len(true_labels)):
        if true_labels[true_label_elmt]==1:
            print('true_label: '+str(true_label_elmt)+','+categories[true_label_elmt])
    print('\n')
# Out:
# item: ENRICHED DURUM _WHEAT_ SEMOLINA SEMOLINA _WHEAT_ NIACIN IRON LACTATE THIAMINE MONONITRATE RIBOFLAVIN FOLIC ACID
# true_label: 351,pasta
#
#
# item: Tomato puree water tomato paste sugar white vinegar red jalapeno puree red jalapeno peppers salt citric acid salt red chili puree red chili peppers salt citric acid garlic puree garlic water citric acid onion powder garlic spices c
# true_label: 393,Ketchup
#
#
# item: Molkenproteinkonzentrat 99_Wheyproteinkonzentrat_ nur Schoko Kakaopulver entölt Aroma Pflanzenöl aus Raps Süßungsmittel AcesulfamK und Sucralose
# label: 1043,Proteinpulver
# true_label: 1043,Proteinpulver
#
#
# item: Sultanas 19 Sugar Water Fortified Wheat Flour Wheat Flour Calcium Carbonate Iron Niacin Thiamin Raisins 14 Currants 4 Palm Oil Humectant Vegetable Glycerine Candied Citrus Peel Glucose Syrup Orange Peel Sugar Lemon Peel Acid Citric Acid Pasteurised Free Range Egg Apple Juice from Concentrate Molasses Orange and Lemon Peel Mixed Spice Coriander Cinnamon Clove Fennel Ginger Nutmeg Cardamom Salt Lemon Juice Yeast Spirit Vinegar Wheat Protein Emulsifier Mono and Diglycerides of Fatty Acids Mono and DiacetylTartaric Acid Esters of Mono and Diglycerides of Fatty Acids Rapeseed Oil Flour Treatment Agent Ascorbic Acid
# true_label: 1,Desserts
# true_label: 7,Cakes
# true_label: 151,Sugary snacks
# true_label: 169,Biscuits and cakes
# true_label: 170,Christmas Puddings
# true_label: 171,Puddings
#
#
# item: Pommes jus de citron concentré
# true_label: 706,Chips de pommes
# true_label: 707,Fruits déshydratés
#
#
# item: Wheat flour vegetable shortening partially hydrogenated palm  canola oils sugar malt syrup lactose whole milk powder skim milk powder emulsifier soyalecithin seasoning natural leavening ammonium bicarbonate  sodium bicarbonate salt sugar flavor milk flavor
# true_label: 890,snacks
# true_label: 1088,cookies
#
#
# item: Jus dorange 60 purée de carottes 40
# true_label: 490,Jus de fruits et de légumes
#
#
# item: Wheat Flour Veqetable Oils Palm Oil Rapeseed Oil Water Palm Fat Soya Flour Salt Emulsifier Mono and Diqlycerides of Fatty AcidsPreservativc Potassium Sorbate
# true_label: 151,Sugary snacks
# true_label: 169,Biscuits and cakes
# true_label: 874,Pastries
# true_label: 875,Shortcrust Pastry
#
#
# item: Orange Peel 42 GlucoseFructose Syrup Lemon Peel 16 Sugar Acidity Regulator Citric Acid Preservative Sulphur Dioxide
# true_label: 221,Peels
#
#
# item: Peach Purée 70 White Grape Juice 30
# true_label: 371,Fruit Juices
#
#
# item: Scottish Lochmuir Salmon _Fish_ 97  Salt
# label: 253,Seafood
# label: 254,Fishes
# label: 255,Salmons
# true_label: 182,Salmon
#
#
# item: Chilean Flame Raisins 28  Oat Flakes contain _Gluten_ 15  Wheatflakes contain _Gluten_ 10  Wheat Bran Flakes 10 Wheatflakes contain _Gluten_  Sugar  Barley Malt Extract contains _Gluten_  Salt  Chopped Dates 10  Toasted Malted Wheatflakes 9 Wheatflakes contain _Gluten_  Barley Malt Extract contains _Gluten_  Toasted Coconut Chips 5  Dried Apricots 4  Golden Linseed  Sunflower Seeds  Pumpkin Seeds  Roasted _Hazelnuts_  Rice Flour  Sunflower Oil  Preservative E220 _Sulphites_
# true_label: 44,Petit-déjeuners
# true_label: 74,Aliments et boissons à base de végétaux
# true_label: 75,Aliments d'origine végétale
# true_label: 433,Céréales et pommes de terre
# true_label: 542,Céréales et dérivés
# true_label: 586,Céréales pour petit-déjeuner
# true_label: 587,Flocons
# true_label: 588,Flocons de céréales
# true_label: 589,Mélanges de flocons de céréales
# true_label: 591,Mueslis
# true_label: 592,Mueslis aux fruits
#
#
# item: Roasted peanuts salt
# true_label: 382,Peanut butters
# true_label: 1106,Crunchy Peanut Butter
#
#
# item: SUGAR CORN SYRUP PARTIALLY HYDROGENATED PALM KERNEL OIL WHEY _MILK_ COCOA CONTAINS 2 OR LESS OF MALTED _MILK_ BARLEY MALT _WHEAT_ FLOUR _MILK_ SALT SODIUM BICARBONATE RESINOUS GLAZE sorbitan tristearate _SOY_ LECITHIN SALT NATURAL AND ARTIFICIAL FLAVORS CALCIUM CARBONATE TAPIOCA DEXTRIN
# true_label: 40,Bonbons
# true_label: 151,Sugary snacks
# true_label: 152,Chocolates
# true_label: 457,Confectioneries
# true_label: 458,Candies
#
#
# item:  Eau Fécule de Maïs Blanc de Poluet cuit 3  Bouillon de poulet rôti eau sel extrait de levure viande de poulet os de poulet fécule de Maïs poivre blanc moulu graines de fenouil moulues feuills de laurier persil ail oignons oireaux carottes crème lait 15 Huile de colza Protelne de laçtoserum Lait graisse de poulet extrait de levure fraine de blé contient Gluten arôme sel poivre blanc moulu
# label: 61,Plats préparés
# true_label: 573,Soupes de poulet
#
#
# item: Poulet cuit 19  Riz parfumé cuit 19 Eau Riz parfumé  Riz long grain cuit 19 Eau  Riz long grain  Eau  Farine de _blé_  Purée de gingembre  Oignons  Farine de riz  Purée d ail Bouillon de poulet Eau  Os de poulet  Huile fe colza  Sauce soja foncée Eau  Fèves de _soja_  _Blé_   Sel  Sucre roux  mirin Eau  Sucre  riz  Alcool  Fécule de maïs  Sel  Purée de tomate  Sucre  pâte mlso rouge Eau  Fèves de _soja_  riz  Sel  Levure  correcteur dacidité  acide lactique  Fécule de pomme de terre  Levure  épices moulues  Coriandre  Cannelle  Curcuma  anis étoilé  Paprika  Cumin  Poivre blanc  Poivre noir  Saké  _Gluten_ de _blé_  Huile de sésame  _Graines de sésame_  vinaigre  Piments rouges  Huile de tournesol  Gélatine de bœuf  correcteur dacidité  acide ascorbique ail déshydraté
# label: 61,Plats préparés
# label: 123,Frais
# true_label: 95,Plats à base de poulet
# true_label: 121,Plats préparés à réchauffer au micro-ondes
# true_label: 312,Plats préparés réfrigérés
#
#
# item: long grain brown rice
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 85,Cereals and potatoes
# true_label: 86,Cereals
# true_label: 162,Rices
#
#
# item: carbonated water high fructose corn syrup citric acid natural flavor potassium benzoate a preservative quinine
# true_label: 297,Sodas
# true_label: 328,Beverages
# true_label: 582,Carbonated drinks
# true_label: 780,Sugared beverages
# true_label: 1019,Tonic water
#
#
# item: Pommes de terre déshydratées Fécule de pomme de terre Huile de tournesol  sel Vinaigre de malt d_orge_ déshydraté Maltodextrine Sucre  Vinaigre déshydraté Acidifiant  Acide citrique Acide malique Acide tartrique  Extrait de levure déshydratée
# true_label: 181,Biscuits apéritifs
#
#
# item: Farine de _blé_ huile de colza sucre _oeufs_ frais 18 sirop de glucosefructose stabilisant  glycérol poudres à lever  carbonates dammonium carbonates de sodium diphosphates _blé_ sel émulsifiants  mono et diglycérides dacides gras _lait_ écrémé en poudre arôme
# label: 3,Gâteaux
# true_label: 0,Snacks sucrés
# true_label: 1,Desserts
# true_label: 2,Biscuits et gâteaux
# true_label: 3,Gâteaux
# true_label: 4,Madeleines
#
#
# item: ORGANIC TOMATO PUREE ORGANIC SUGAR ORGANIC WHITE VINEGAR SALT ORGANIC ONION POWDER ORGANIC SPICES
# true_label: 393,Ketchup
#
#
# item: _OAT_ BRAN BLUEBERRIES WHOLE RYE FLOUR BLENDED WHITE GRAPE JUICE CONCENTRATE WATER PINEAPPLE RASPBERRIES CANOLA OIL BAKING SODA SODIUM BICARBONATE SALT
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 85,Cereals and potatoes
# true_label: 401,Breads
# true_label: 402,Muffins
#
#
# item: Flaked Almonds
# true_label: 223,Almonds
# true_label: 224,Salty snacks
# true_label: 225,Nuts
# true_label: 800,Flaked Almonds
#
#
# item: Jus dananas du Costa Rica  98Jus de citron vert
# true_label: 74,Aliments et boissons à base de végétaux
# true_label: 241,Boissons
# true_label: 242,Boissons à base de végétaux
# true_label: 243,Boissons aux fruits
# true_label: 244,Jus et nectars
# true_label: 245,Jus et nectars de fruits
# true_label: 246,Jus de fruits
# true_label: 247,Jus d'ananas
# true_label: 248,Jus de fruits 100% pur jus
#
#
# item: CARBONATED WATER HIGH FRUCTOSE CORN SYRUP CITRIC ACID NATURAL FLAVORS SODIUM CITRATE SODIUM BENZOATE TO PROTECT TASTE
# true_label: 955,soda
#
#
# item: Carbonated water caramel color aspartame phosphoric acid natural and artificial flavors sodium benzoate preservative caffeine Phenylketonurics contains phenylalanine
# label: 297,Sodas
# label: 328,Beverages
# label: 582,Carbonated drinks
# true_label: 297,Sodas
# true_label: 328,Beverages
# true_label: 394,Non-sugared beverages
# true_label: 582,Carbonated drinks
# true_label: 784,Diet sodas
# true_label: 956,Artificially sweetened beverages
# true_label: 957,Diet beverages
#
#
# item: Farine de _blé_ contient _Gluten_ avec Farine de _blé_ Carbonate de calcium Fer Niacine Thiamine  Blanc de poulet dorigine britannique 17  Eau  Yaourt à la grecque _Lait_  Riz long grain Eau  Riz long grain  Huile de tournesol  émulsifiant  E471   Haricots noirs  Épinards  Mangue  Poivrons rouges  Poivrons jaunes  Purée de mangue  Huile de palme  Sucre  Oignons de printemps  Jus de citron vert  Huile de colza  Épices moulues Gingembre  Anis étoilé  Clous de girofle   Piment de Cayenne  Cannelle  Graines de fenouil  Poivre noir  Poivre blanc  Cumin  Fécule de maïs  Huile de tournesol  Miel  Poudre à lever  Bicarbonate de soude E450 Acide malique  Sel  Piments rouges  Sucre Demerara  Thym  Ail déshydraté  Flocons de paprika  Poudre de piment  Poivre noir concassé  Sel de mer Persil  déshydraté  Acidifiant  Acide citrique  _Affermissant  E509
# true_label: 61,Plats préparés
# true_label: 123,Frais
# true_label: 124,Plats préparés frais
# true_label: 130,Sandwichs
# true_label: 137,Sandwichs à la volaille
# true_label: 138,Sandwichs au poulet
# true_label: 139,Wrap
#
#
# item: Sugar Mango 46 Salt Acidity Regulator Acetic Acid Paprika Cayenne Pepper
# true_label: 475,Mango chutney
#
#
# item: Vegetable Glycerine Propylene Glycol Water Emulsifier Polysorbate 80 Colours Carmine Curucumin Acidity Regulator Potassium Hydroxide
# true_label: 898,Food Colouring
#
#
# item: Tapioca flour high oleic sunflower oil prawns _crustacean_ sugar salt condensed cows _milk_
# true_label: 803,Crisps
#
#
# item: vinaigre de vin moult de raisin concentré colorant E150d antioxygène sulfites E224
# true_label: 1091,Vinaigre balsamique
#
#
# item: Farine de blé contient Gluten avec Farine de blé Carbonate de calcium Fer Niacine Thiamine  Viande de canard dorigine britannique rôtie 21   Eau  Sauce hoisin 10 Eau  Sucre muscovado  Sucre  Fèves de soja   Jus de prune concentré  Concentré de tomate  Sel  Fécule de maïs  Sirop de sucre noir  Purée de gingembre  Purée de piment  Huile de tournesol  Vinaigre de vin rouge  Sirop de sucre  Vinaigre de riz  Epices moulues Cannelle  Gingembre  Fenouil  Anis  Clous de girofle  Vinaigre de malt dorge contient Gluten  Extrait de malt dorge contient Gluten  Farine de blé contient Gluten avec Farine de blé Carbonate de calcium Fer Niacine Thiamine  Correcteur dacidité  Acide acétique  Concombre 7  Épinards  Huile de palme  Oignons de printemps  Humectant  Glycérol  Sucre  Huile de colza  Vinaigre dalcool de riz  Sucre muscovado  Sel  Fèves de soja  Blé contient Gluten  Emulsifiant  E471  Epices moulues Gingembre  Anis étoilé  Cannelle  Fenouil  Clous de girofle  Poudre à lever  Acide malique  Agent de traitement de la farine  E920 Acidifiant  Acide citrique
# true_label: 661,en:sandwiches
# true_label: 662, fr:wrap
#
#
# item: Fruits 374 fruits confits 215 fruits pastèque bigarreaux écorce dorange sirop de glucosefructose sucre conservateurs  sorbate de potassium  anhydride sulfureux colorants  caramel ordinaire  E120 E133 correcteur dacidité  acide citrique raisins secs au rhum 159 farine de blé huile de colza œufs frais sucre sirop de glucosefructose stabilisant  glycérol poudres à lever  carbonates dammonium  carbonates de sodium  diphosphates blé sel émulsifiants  mono et diglycérides dacides gras lait écrémé en poudre arôme naturel dorange
# true_label: 0,Snacks sucrés
# true_label: 1,Desserts
# true_label: 2,Biscuits et gâteaux
# true_label: 3,Gâteaux
# true_label: 8,Pâtisseries
# true_label: 9,Cakes aux fruits
#
#
# item: Rapeseed Oil 71 Pasteurised Free Range Egg Yolk 7 Water Spirit Vinegar Roasted Garlic Purée 3 Garliç Purée 3 Sugar Salt Concentrated Lemon Juice Yellow Mustard Flour Dried Garlic Preservative E202
# true_label: 110,Epicerie
# true_label: 112,Sauces
# true_label: 502,Mayonnaises
#
#
# item: WATER ORGANIC CARROTS ORGANIC CELERY ORGANIC ONIONS ORGANIC TOMATOES ORGANIC CARROT JUICE CONCENTRATE ORGANIC TOMATO PASTE ORGANIC LEEKS ORGANIC GARLIC ORGANIC ONION JUICE CONCENTRATE SEA SALT ORGANIC SEASONINGS PARSLEY THYME BAY LEAF BLACK PEPPER ORGANIC OLIVE OIL
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 283,Groceries
# true_label: 691,Broths
# true_label: 692,Liquid broths
# true_label: 728,Vegetable broths
# true_label: 729,Liquid vegetable bouillons
#
#
# item: Water  Apple juice from concentrate  glucose syrup  sugar  carbon dioxyd  acidity regulator  lactic acid malic acid  preservative  E224 _sulphites_  yeast
# true_label: 241,Boissons
# true_label: 466,Boissons alcoolisées
# true_label: 469,Cidres
# true_label: 470,Cidres demi-secs
#
#
# item: Olive oil
# label: 557,Extra Virgin Olive Oils
# true_label: 558,Extra-virgin olive oils
#
#
# item: Château Notton Margaux vin rouge Bordeaux _sulfites_
# true_label: 241,Boissons
# true_label: 466,Boissons alcoolisées
# true_label: 529,Vins
# true_label: 530,Vins français
# true_label: 531,Bordeaux
# true_label: 532,Vins du Médoc
# true_label: 533,Margaux
#
#
# item: Syrah
# true_label: 858,French wines
# true_label: 859,Red wines
#
#
# item: Lemon Juice from concentrate _Sulphites_ Lemon Oil Preservative Potassium Metabisulphite _Sulphites_
# true_label: 778,Lemon juice
#
#
# item: Cocoa Mass Suqar Cocoa Butter Vanilla Flavourinq
# true_label: 152,Chocolates
# true_label: 458,Candies
# true_label: 893,Dark chocolate
#
#
# item: Tomato puree water tomato paste sugar white vinegar red jalapeno puree red jalapeno peppers salt citric acid salt red chili puree red chile peppers salt citric acid garlic puree garlic water citric acid onion powder garlic spices clove allspice red pepper habanero pepper powder
# true_label: 393,Ketchup
#
#
# item: Sirop dérable
# true_label: 597,en:sweeteners
# true_label: 598, en:syrups
# true_label: 599, en:simple-syrups
# true_label: 600, en:maple-syrups
#
#
# item: Water Organic Garbanzo Beans Sea Salt
# true_label: 1113,Canned Beans
#
#
# item: ALMONDMILK FILTERED WATER _ALMONDS_ EVAPORATED CAN JUICE CALCIUM CARBONATE SEA SALT POTASSIUM CITRATE CARRAGEENAN SUNFLOWER LECITHIN VITAMIN A PALMITATE VITAMIN D2 AND DALPHATOCOPHEROL NATURAL VITAMIN E
# label: 946,Almond milks
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 289,Nuts and their products
# true_label: 328,Beverages
# true_label: 394,Non-sugared beverages
# true_label: 822,Plant-based beverages
# true_label: 946,Almond milks
# true_label: 982,Milk substitute
# true_label: 983,Plant milks
# true_label: 984,Nut milks
#
#
# item: distilled _barley_ malt vinegar acidity 5
# true_label: 902,Distilled malt vinegar
# true_label: 903,Malt vinegar
#
#
# item: sugar corn syrup white grape juice from concentrate gelatin citric acid tartaric acid fumaric acid sorbitol natural  artificial flavours silicon dioxide anticaking agent artificial colours fdc red 40 yellow 6 blue 1 yellow 5
# true_label: 151,Sugary snacks
# true_label: 457,Confectioneries
# true_label: 458,Candies
#
#
# item: _Hartweizengrieß_
# true_label: 941,Lasagne
#
#
# item: Huile dolive de catégorie supérieure obtenue directement des olives et uniquement par des procédés mécaniques
# true_label: 74,Aliments et boissons à base de végétaux
# true_label: 75,Aliments d'origine végétale
# true_label: 925,Matières grasses
# true_label: 926,Produits de l'olivier
# true_label: 927,Matières grasses végétales
# true_label: 928,Huiles
# true_label: 929,Huiles d'olive
# true_label: 930,Huiles d'olive vierges
# true_label: 931,Huiles d’olive vierge extra
#
#
# item: eau gazéifiéesucreglucosefructoseacide citriqueessence naturellebenzoate de sodiumcolorant
# label: 241,Boissons
# label: 438,Boissons non sucrées
# true_label: 955,soda
#
#
# item: British Pork 36 Wheatflour Wheatflour Calcium Carbonate Iron Niacin Thiamin Pork Lard Pork Fat Palm oil Rapeseed Oil Salt Potato Starch Pork Stock Pork Pork Bones Pork Fat Water Pasteurised Free Range Egg Pork Gelatine Ground White Pepper Ground Nutmeg Raising Agent E503
# true_label: 349,Pork Pie
#
#
# item: Galangal 50 water rapeseed oil 10 spirit vinegar 8 sugar salt cornflour
# true_label: 112,Sauces
# true_label: 283,Groceries
#
#
# item: Pomme de terre 83  amidon de pomme de terre huile de palme _œuf_ épices oignon curcuma farine de riz sel farine de _blé_ dextrose
# true_label: 60,Surgelés
# true_label: 66,Plats préparés surgelés
# true_label: 336,Rostis
#
#
# item: Water peas 25 potatoes onions 10 ham 45 pork salt preservative sodium nitrite leeks 4 salted butter vegetable bouillon salt yeast extract rice flour dried onlon dried carrot parsley ground turmeric salt garlic parsley mint white pepper
# true_label: 1022,Soup
#
#
# item: Raisin rouge sans pépin variété Allison
# label: 74,Aliments et boissons à base de végétaux
# label: 75,Aliments d'origine végétale
# label: 76,Aliments à base de fruits et de légumes
# label: 319,Fruits
# label: 607,Fruits et produits dérivés
# label: 672,Raisins
# label: 673,Raisins rouges sans pépins
# true_label: 672,Raisins
# true_label: 680,Raisins rouges
#
#
# item: Onion 37sugar water spirit vinegar modified maize starch salt caramelised sugar syrup dried onion dried red pepper mustard seed spices
# label: 112,Sauces
# label: 283,Groceries
# true_label: 112,Sauces
# true_label: 283,Groceries
#
#
# item: ground cinnamon
# true_label: 421,Ground cinnamon
#
#
# item: sirop sirop de glucose huile de coprah hydrogénée acidifiants acide citrique acide tartrique gélatine arômes colorants  E163 E161b E133 émulsifiant  E473
# true_label: 40,Bonbons
# true_label: 739,Confiseries
#
#
# item: Sweetcorn 83 Water Sugar Salt
# true_label: 843,Sweetcorn
#
#
# item: Carbonated Water High Fructose Corn Syrup Caramel Color Phosphoric Acid Natural Flavors Caffeine
# label: 297,Sodas
# label: 328,Beverages
# label: 582,Carbonated drinks
# label: 779,Colas
# label: 780,Sugared beverages
# true_label: 297,Sodas
# true_label: 328,Beverages
# true_label: 582,Carbonated drinks
# true_label: 779,Colas
# true_label: 780,Sugared beverages
#
#
# item: Sugar Cornflour Flavouring Gelling Agents Carrageenan Tetrasodium Diphosphate Potassium Citrate Acidity Regulator Sodium Citrate Exhausted Vanilla Beans Colour Algal Carotenes
# true_label: 208,preparation for panna cotta
# true_label: 209,preparation for dessert
#
#
# item: Pommes de terre  Huile de tournesol  Lait déshydraté _Lait_  Fromage Cheddar mûr déshydraté _Lait_  Sel  Oignons rouges séchés  Oignons séchés  _Babeurre_ séché  Levure sèche  Extrait de levure séchée  Aromatisant  Acide Acide citrique  Couleur Extrait de paprika  Ail séché
# true_label: 38,Chips
# true_label: 156,Snacks salés
# true_label: 157,Apéritif
# true_label: 158,Chips et frites
# true_label: 1074,Chips de pommes de terre
# true_label: 1075,Chips cheddar et onion
#
#
# item: Enriched Durum Semolina Durum _Wheat_ Flour Niacin Iron Thiamine Riboflavin Folic Acid Dried Spinach Dehydrated Onion Onion Powder Dried _Egg_ Whites Spice Chives Onion Concentrate Sunflower Oil
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 85,Cereals and potatoes
# true_label: 172,Cereals and their products
# true_label: 173,Pastas
#
#
# item: Organic durum wheat semolina
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 85,Cereals and potatoes
# true_label: 172,Cereals and their products
# true_label: 173,Pastas
#
#
# item: Water _Soy_ Sauce 39 Water _Soy_ Beans _Soya_ Salt  _Wheat_ Flour Sugar Colour Plain Caramel Acidity Regulator Lactic Acid Preservative Potassium Sorbate Salt
# true_label: 860,Soy sauces
#
#
# item: Farine de _blé_ contient _Gluten_ avec Farine de _blé_ Carbonate de calcium Fer Niacine Thiamine  Eau  Fromage mozzarella végétarien _Lait_ 12  Tomates  Poivrons jaunes 7 Courgette 7  Tomates cerises rouges Santarella 45 Tomates cerises  Huile de tournesol  Ail déshydraté  Origan  Sel  Correcteur dacidité  acide citrique   Purée de tomates  Oignons rouges  Huile de colza  Huile dolive vierge extra  Basilic Huile de tournesol  Farine complète de _blé_ contient _Gluten_  Sel  Fromage à pâte dure végétarien _Lait_  Levure  Vinaigre Balsamique  Sucre  Semoule de _blé_ contient _Gluten_  Farine de _blé_ malté contient _Gluten_  Fécule de maïs  Purée dail  Antioxydant  acide citrique  Poivre noir moulu  Fécule de pomme de terre
# true_label: 61,Plats préparés
# true_label: 62,Pizzas tartes salées et quiches
# true_label: 65,Pizzas
# true_label: 432,Pizzas aux légumes grillés
#
#
# item: Thé vert nature bio
# true_label: 511,Thés verts
#
#
# item: ORGANIC ROASTED _SOY_ NUTS ORGANIC _SOYBEANS_ ORGANIC _SOYBEAN_ OIL SALT
# true_label: 224,Salty snacks
# true_label: 225,Nuts
#
#
# item: chicken
# true_label: 782,frozen chicken
#
#
# item: Enriched unbleached flour wheat flour malted barley flour reduced iron thiamine mononitrate vitamin b1 riboflavin vitamin b2 niacin vitamin b3 folic acid water sugar yeast soybean oil salt wheat gluten monoglycerides calcium propiona
# label: 350,fr:Pains-Burgers
# true_label: 350,fr:Pains-Burgers
#
#
# item: Water Blueberry Juice from Concentrate 27 Sugar Lemon Juice from Concentrate Blueberry Purée 4
# true_label: 327,Juice Drink
# true_label: 328,Beverages
#
#
# item: Dill
# true_label: 32,Herbs
# true_label: 269,dill
#
#
# item: Mint
# label: 32,Herbs
# label: 795,Fresh Herbs
# true_label: 32,Herbs
#
#
# item: Wheatflour contains Gluten With nuti Wheatflour Calcium Carbonate Iron Niacin Thiamin  Butter Milk 22  Sugar  Oat Flakes contain Gluten  Belgian Dark Chocolate Chunks 7 Sugar  Cocoa Mass  Cocoa Butter  Emulsifier Soya Lecithin  Vanilla Flavouring  Crystallised Stem Ginger 7 Stem Ginger  Sugar  Hazelnuts 3  Belgian Milk Chocolate Chunks Sugar  Dried Whole Milk  Cocoa Butter  Cocoa Mass  Emulsifier Soya Lecithin  Vanilla Flavouring  Diced Pecan Nuts  Currants  Golden Syrup Invert Sugar Syrup Sunflower Seeds  Dried Skimmed Milk  Pumpkin Seeds  Raising Agent Sodium Bicarbonate E450 E503  Invert Sugar Syrup  Salt  Ground Ginger  Flavouring Belgian Dark Chocolate Chunks contain Cocoa Solids 39 minimum Belgian Milk Chocolate Chunks contain Cocoa Solids 25 minimum and Milk Solids 14 minimum For allergens see ingredients in bold Suitable for vegetarians
# true_label: 0,Snacks sucrés
# true_label: 2,Biscuits et gâteaux
# true_label: 22,Biscuits
# true_label: 1071,Biscuits secs
# true_label: 1072,Assortiments de biscuits
# true_label: 1073,Biscuits pur beurre
#
#
# item: Sugar Wheat Starch Colour Beetroot Red Curcumin Anthocianins Glucose syrup Glazing agent Beeswax Coconut Oil
# true_label: 151,Sugary snacks
# true_label: 457,Confectioneries
# true_label: 458,Candies
#
#
# item: Farine de blé contient Gluten avec Farine de blé Carbonate de calcium Fer Niacine Thiamine  Raisins secs 17 Raisins de Smyrne  Raisins de Corinthe Vostizza  Raisins  Beurre Lait 14  Sucre  Sirop de glucosefructose  Purée de pomme  Cerises confites 35 Cerises  Sirop de glucosefructose  Sucre  Colorant  Anthocyanes issus de Carottes noires  Correcteur dacidité  Acide citrique  Brandy 2  Butteroil Lait  Jus de clémentine concentré  Canneberges  Dextrose  Huile de tournesol  Fécule d9 maïs  Écorces dorange et de citron confites Écorce dlorange  Sirop de glucosefructose  Sucre  Ecorce de citron  Correcteur dacidité  Acide citrique  Épices moulues Cannelle  Noix de muscade  Conservateur  Acide acétique  Sel  Gélifiant  Pectine issue de Fruits  Sirop de sucre  Huile de palme  Correcteur dacidité  Acide citrique  Huile dlorange  Poudre à lever  E450 Bicarbonate de soude Pour les allergènes voir les
# true_label: 303,en:sugary-snacks
# true_label: 304, en:biscuits-and-cakes
# true_label: 742, en:pastries
# true_label: 743, fr:Mince Pies
#
#
# item: water Wheat Flour 45 Sunflower Oil Wheat gluten Salt Lactic Acid
# true_label: 198,Ribbon noodles
#
#
# item: MADE WITH SMILES AND UNBLEACHED ENRICHED _WHEAT_ FLOUR FLOUR NIACIN REDUCED IRON THIAMINE MONONITRATE VITAMIN B1 RIBOFLAVIN VITAMIN B2 FOLIC ACID CHEDDAR _CHEESE_ CULTURED _MILK_ SALT ENZYMES ANNATTO VEGETABLE OILS CANOLA SUNFLOWER ANDOR _SOYBEAN_ CONTAINS 2 PERCENT OR LESS OF SALT YEAST SUGAR AUTOLYZED YEAST LEAVENING BAKING SODA MONOCALCIUM PHOSPHATE AMMONIUM BICARBONATE PAPRIKA SPICES CONTAINS _CELERY_ AND DEHYDRATED ONIONS
# true_label: 302,Crackers
#
#
# item: Pasteurised culture cream
# true_label: 632,Crème fraîche
# true_label: 832,Pasteurised culture cream
#
#
# item:  Farine de _blé_ contient _Gluten_ avec Farine de _blé_ Carbonate de calcium Fer Niacine Thiamine  Fromage mozzarella _lait_ 12  Épinards 10  Tomates concassées 10  Eau  Fromage ricotta _lait_ 5  Tomates cerises Santarella marinées semiséchées 5  Tomates cerises  huile de tournesol  ail déshydraté  Origan  Sel  Purée de tomate 3  Huile de colza  sucre  levure  sel  dextrose  beurre _lait_  Poivre noir grossièrement moulu  Huile dolive vierge extra  Basilic  Purée dail  Fécule de maïs  Noix de muscade moulue  Fécule de pomme de terre  Huile de tournesol
# true_label: 61,Plats préparés
# true_label: 62,Pizzas tartes salées et quiches
# true_label: 65,Pizzas
# true_label: 123,Frais
# true_label: 124,Plats préparés frais
#
#
# item: PURE FILTERED WATER SUGAR LEMON JUICE NATURAL FLAVORS
# true_label: 297,Sodas
# true_label: 328,Beverages
# true_label: 582,Carbonated drinks
# true_label: 583,Lemonades
#
#
# item: pasteurized British double fresh cream
# true_label: 211,Dairies
# true_label: 817,Creams
# true_label: 818,Double cream
#
#
# item: Carbonated Water High Fructose Corn Syrup Concentrated Orange Juice Citric Acid Natural Flavor Sodium Benzoate preserve freshness Caffeine Sodium Citrate Erythorbic Acid preserve freshness Gum Arabic Calcium Disodium Eota to protect flavor Brominated vegetable oil Yellow 5
# true_label: 297,Sodas
# true_label: 328,Beverages
# true_label: 582,Carbonated drinks
# true_label: 780,Sugared beverages
#
#
# item: Sauce à la mayonnaise 25 Eau  Huile de colza  Fécule de maïs  Huile de colza pressée à froid  Jaune d_œufs_ de poules élevées en plein air pasteurisés  Vinaigre  _Œufs_ de poules élevées en plein air pasteurisés  Sel  Jus de citron concentré  Graines de _moutarde_ noire  Farine de _moutarde_  Farine de blé contient _Gluten_ avec Farine de blé Carbonate de calcium Fer Niacine Thiamine  Fromage cheddar _Lait_ 18  Eau  Fromage red leicester 9 Fromage red leicester _Lait_  Colorant  Rocou  Oignons rouges 45  Avoine grossièrement moulue  Son de blé contient Gluten  Levure Levure  Levure  enrichie en vitamine D  Sel  Vinaigre  Émulsifiant  E471  E472e  _Gluten_ de blé  Huile de colza  Farine dorge malté contient _Gluten_   Sucre  Huile de palme  Agent de traitement de la farine  Acide ascorbique  Graisse de palme
# true_label: 130,Sandwichs
# true_label: 663,Sandwichs au fromage
#
#
# item:  Sugar Water Garlic 11 Red Chilli 10 fructoseglucose syrup maize starch salt acidity regulator acetic acid
# true_label: 112,Sauces
# true_label: 283,Groceries
#
#
# item: Milled corn sugar contains 2 or less malt flavor salt BHT for freshness  Vitamins and Minerals iron vitamin C ascorbic acid and sodium ascorbate niacinamide vitamin B6 pyridoxine hydrochloride vitamin B2 riboflavin vitamin B1 thiamin hydrochloride vitamin A palmitate folic acid vitamin D vitamin B12
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 85,Cereals and potatoes
# true_label: 172,Cereals and their products
# true_label: 187,Breakfasts
# true_label: 292,Breakfast cereals
# true_label: 977,Corn flakes
#
#
# item: Sugar glucose syrup citric acid artificial flavors red 40 red 3 yellow 5 yellow 6 blue 1
# true_label: 151,Sugary snacks
# true_label: 457,Confectioneries
# true_label: 458,Candies
# true_label: 1095,Lollipops
#
#
# item: Almonds
# label: 224,Salty snacks
# label: 225,Nuts
# label: 226,Ground almonds
# true_label: 223,Almonds
# true_label: 224,Salty snacks
# true_label: 225,Nuts
#
#
# item: Sucre 74  sirop de glucose huiles et graisses végétales palme tournesol illipé sirop de sucre inverti stabilisant  E420ii eau humectant  E422 épaississant  E415 émulsifiant  E471 acidifiant  E330 arôme conservateur
# true_label: 1051,Pâtes à sucre
# true_label: 1052,Décorations
# true_label: 1053,fr:Confiseries
#
#
# item: Porc britannique élevé en plein air 85  Eau  Blancs d_œuf_ de poules élevées en plein air pasteurisés  chapelure sans gluten Farine de riz  Farine de pois chiches  Farine de maïs  Sel  Dextrose  Sel  Sauge séchée  Sauge  Poivre noir broyé  Extrait de levure  Persil  Stabilisateur E450  Coriandre broyée  Noix de muscade en poudre  conservateur E223 _sulfites_  Antioxydant Acide ascorbique
# true_label: 122,Plats à base de viande porcine
# true_label: 306,Saucisses
# true_label: 339,Saucisses de porc
#
#
# item: Finger chillies
# label: 653,chillies
# true_label: 653,chillies
#
#
# item: Viande de bœuf Aberdeen Angus 29  Farine de _blé_ contient _Gluten_ avec Farine de _blé_ Carbonate de calcium Fer Niacine Thiamine  Tomates mûries sur pied  Eau  Chutney doignons rouges caramélisés 8 Oignons rouges  Sucre  Vinaigre de malt d_orge_ contient _Gluten_  Vinaigre balsamique  Eau  Gélifiant  Pectine  Purée de gingembre Purée dail rôti  Sel  Purée de piment rouge  Crème fraîche britannique _Lait_  Cresson  _Beurre_ _Lait_  Huile de   palme  Oignons blancs  Sel  Levure Levure  Levure enrichie en vitamine D  Huile dolive  Graines de _moutarde_ brune  Vinaigre de vin blanc  Farine de _moutarde_  Vinaigre  Huile de colza  Émulsifiant  E472e  Fécule de mais  Épices moulues Cannelle  E Piments  Curcuma  Son de _moutarde_  Agent de traitement de la farine  Acide ascorbique
# true_label: 124,Plats préparés frais
# true_label: 136,Sandwichs au bœuf
#
#
# item: Eau gazéifiée sirop de fructoseglucose acidifiant E330 arôme pastèque Colorant E129
# true_label: 281,en:beverages
#
#
# item: Sugar Rice Flour Cocoa Butter Thickener Tragacanth Safflower Concentrate Colour Beetroot Red
# true_label: 151,Sugary snacks
# true_label: 457,Confectioneries
# true_label: 458,Candies
#
#
# item: White rice flour potato starch cane sugar dehydrated pumpkin flakes pumpkin maltodextrin corn flour sunflower lecithin an emulsifier buttermilk powder milk tapioca flour molasses power molasses maltodextrin baking powder sodium acid pyrophosphate baking soda monocalcium phosphate sea salt organic vanilla flavor expeller pressed canola oil ground cinnamon ground allspice ground ginger xanthan gum annatto for color annatto powder maltodextrin ground nutmeg
# true_label: 377,Pancakes and waffles
#
#
# item: Contient du _gluten_
# true_label: 119,Bières
# true_label: 1097,Bières anglaises
# true_label: 1098,Bières noires
# true_label: 1099,Porter
#
#
# item: biscuits salés à la pomme de terre INGRÉDIENTS Fécule de pomme de terre  Pommes de terre déshydratées  Huile de tournesol Farine de riz Farino de maïs  Sel
# true_label: 546,en:Biscuits apéritifs
#
#
# item: Tomatoes
# label: 18,Vegetables based foods
# label: 112,Sauces
# label: 284,Tomatoes and tomato products
# true_label: 1112,Tomato paste
#
#
# item: chicken drumsticks 51 chicken thighs 41 lemon 3 piri piri seasoning 3 sugar corn flour salt cumin chilli pepper black pepper dried red pepper chilli dried green pepper parsley oregano red chilli pepper sunflower oil paprika extract garlic chilli extract monoglycerides of fatty acids diglycerides of fatty acids
# true_label: 233,Meats
# true_label: 234,Poultries
# true_label: 235,Chickens
# true_label: 236,Piri Piri chicken
#
#
# item: Riz long grain cuit 26 Eau Riz long grain Tomates Eau Blanc de Poulet cuit 12 Oignons Poivrons verts 4 _Céleri_ Poivrons rouges 25  Jambon cuit fumé effiloché Viande de Porc 93 Eau sels de salaison sel conservateur nitrite de sodium nitrate de sodium Huile de colza Purée de tomates Purée dail Épices moulues Cumin Paprika fumé Paprika Poivre noir Piment de Cayenne Piment Chipotle Piment  de la Jamaïque Poivre blanc Feuilles de laurier Sauce au piment rouge Eau vinaigre Poudre de piment Sel Fécule de maïs Tomates séchées Fécule de maïs Bouillon de poulet Eau Os de poulet Vinaigre de vin blanc Sel Origan Thym Ail déshydraté Romarin déshydraté Basilic déshydraté Jus de citron concentré
# label: 61,Plats préparés
# label: 121,Plats préparés à réchauffer au micro-ondes
# label: 123,Frais
# label: 124,Plats préparés frais
# true_label: 61,Plats préparés
# true_label: 93,Plats à base de viande
# true_label: 94,Plats à base de volaille
# true_label: 95,Plats à base de poulet
# true_label: 96,Plats préparés à faible teneur en matières grasses
# true_label: 121,Plats préparés à réchauffer au micro-ondes
#
#
# item: Sultanas 33 Sugar Cider 13 Fortified Wheat Flour Wheat Flour Calcium Carbonate Iron Niacin Thiamin Palm Oil Humectant Glycerine Orange Peel Candied Citrus Peel Glucose Syrup Orange Peel Sugar Lemon Peel Acid Citric Acid Raisins Sherry 17 Rum Brandy Treacle Molasses Lemon Peel Mixed Spice Coriander Cinnamon Clove Fennel Ginger Nutmeg Cardamom Salt Yeast Orange Oil
# label: 1,Desserts
# label: 7,Cakes
# label: 151,Sugary snacks
# label: 169,Biscuits and cakes
# label: 170,Christmas Puddings
# label: 171,Puddings
# true_label: 1,Desserts
# true_label: 7,Cakes
# true_label: 151,Sugary snacks
# true_label: 169,Biscuits and cakes
# true_label: 170,Christmas Puddings
# true_label: 171,Puddings
#
#
# item: Whole Shelled Pistachios
# true_label: 224,Salty snacks
# true_label: 225,Nuts
# true_label: 340,Pistachios
#
#
# item: Spring Onions
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 17,Fruits and vegetables based foods
# true_label: 18,Vegetables based foods
# true_label: 19,Fresh foods
# true_label: 20,Fresh vegetables
# true_label: 28,Fresh herbs
#
#
# item: HIGH FRUCTOSE CORN SYRUP CORN SYRUP WATER COCOA SUGAR CONTAINS 2 OR LESS OF POTASSIUM SORBATE PRESERVATIVE SALT MONO AND DIGLYCERIDES XANTHAN GUM POLYSORBATE 60 VANILLIN ARTIFICIAL FLAVOR
# true_label: 328,Beverages
# true_label: 394,Non-sugared beverages
# true_label: 780,Sugared beverages
# true_label: 936,Syrups
# true_label: 937,Flavoured syrups
#
#
# item: Dried Vine Fruits 45 Sultanas Raisins Currants Sugar Wheatflour Wheatflour Calcium Carbonate Iron Niacin Thiamin Vegetable Suet Palm Oil Rice Flour Sunflower Oil Water Cider 3 Dark Rum 3 Humectant Glycerol Black Treacle Molasses Orange Peel Amontillado Sherry 1 Nibbed Almonds Glucose Syrup Lemon Peel Ground Spices Coriander Cinnamon Ginger Nutmeg Caraway Cloves Salt Yeast Vinegar Wheat Gluten Emulsifier E471 E472e Rapeseed Oil Palm Oil Acidity Regulator Citric Acid Flour Treatment Agent Ascorbic Acid
# label: 170,Christmas Puddings
# true_label: 1,Desserts
# true_label: 7,Cakes
# true_label: 151,Sugary snacks
# true_label: 169,Biscuits and cakes
# true_label: 170,Christmas Puddings
# true_label: 171,Puddings
#
#
# item: Jus de pomme  Sucre  Dioxyde de carbone  Correcteur dacidité  Acide malique  Conservateur  E223 _Sulfites_  Levure
# true_label: 469,Cidres
# true_label: 470,Cidres demi-secs
#
#
# item: mixed chillies
# true_label: 774,mixed chillies
#
#
# item: Cheddar Cheese Cows _Milk_
# label: 211,Dairies
# label: 212,Cheeses
# true_label: 211,Dairies
# true_label: 212,Cheeses
# true_label: 213,Cheeses from the United Kingdom
# true_label: 214,Cheeses from England
# true_label: 215,Cheddar cheese
#
#
# item: TOMATO CONCENTRATE FROM RED RIPE TOMATOES DISTILLED VINEGAR HIGH FRUCTOSE CORN SYRUP CORN SYRUP SALT SPICE ONION POWDER NATURAL FLAVORING
# label: 112,Sauces
# label: 393,Ketchup
# true_label: 797,Ketchups
#
#
# item: Fortified British Wheat Flour _wheat_ flour calcium carbonate niacin iron thiamin
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 85,Cereals and potatoes
# true_label: 86,Cereals
# true_label: 87,Flours
# true_label: 88,Plain Flour
#
#
# item: dwarf beans
# label: 15,Plant-based foods and beverages
# label: 16,Plant-based foods
# label: 17,Fruits and vegetables based foods
# label: 18,Vegetables based foods
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 17,Fruits and vegetables based foods
# true_label: 18,Vegetables based foods
# true_label: 760,Beans
# true_label: 761,Fine beans
# true_label: 762,Green beans
# true_label: 763,Dwarf beans
# true_label: 764,French beans
#
#
# item: Durum wheat semolina
# true_label: 174,Pasta
#
#
# item: noix de cajou 41 cacahuètes 41 sucre huile de palme miel sirop de glucose sel stabilisant  gomme xanthane
# true_label: 224,Salty snacks
# true_label: 290,Cashew nuts
# true_label: 308,Appetizers
#
#
# item: free range British eggs
# label: 203,Eggs
# label: 702,Farming products
# true_label: 203,Eggs
# true_label: 702,Farming products
#
#
# item: British beef mince 5 fat
# true_label: 81,Beef
# true_label: 249,Fresh meats
#
#
# item: gin
# true_label: 809,Gin
#
#
# item: Raisins secs 46Raisins de Smyme  Raisins  Raisins de Corinthe  Sucre  Farine de _blé_ contient _Gluten_ avec Farine de _blé_ Carbonate de calcium Farine de riz  Huile de tournesol  Cidre britannique 3  Rhum brun 3  Humectant  Glycérol  Sirop de sucre noir  Sirop de sucre  Écorce dorange  Xérès amontillado 1  Sirop de glucose  Écorce de citron  Épices moulues Coriandre  Clous de girofle  Sel  _Amandes_ en poudre  Levure  Huile de palme  Vinaigre  _Gluten_ de _blé_  Émulsifiant  E471 E472e  Huile de colza  Correcteur dacidité  Acide citrique  Agent de traitement de la farine  Acide ascorbique
# true_label: 651,en:desserts
# true_label: 652, en:puddings
#
#
# item: Äpfel 92 Zucker Citronensäure Ascorbinsäure
# true_label: 904,Applesauces
#
#
# item: Rapeseed Oil 61 Water Basil 8 Pasteurised Free Range Egg Yolk 5 Sugar Spirit Vinegar Vegetarian Regato Cheese 15 contains Potato Starch White Wine Vinegar Salt Extra Virgin Olive Oil Cornflour Garlic Purée Lactîc Acid Preservative E202 Concentrated Lemon Juice
# true_label: 603,Sauce
#
#
# item: Chicken
# true_label: 864,fresh chicken
#
#
# item: eau _orge_ malté _blé_ torréfié sucre Demerara dioxyde de carbone houblon levure
# label: 119,Bières
# true_label: 119,Bières
#
#
# item: closed cup chesà uf mushrooms   5
# label: 15,Plant-based foods and beverages
# label: 16,Plant-based foods
# label: 19,Fresh foods
# label: 35,Fresh plant-based foods
# label: 56,Mushrooms and their products
# label: 57,Mushrooms
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 17,Fruits and vegetables based foods
# true_label: 18,Vegetables based foods
# true_label: 19,Fresh foods
# true_label: 35,Fresh plant-based foods
# true_label: 56,Mushrooms and their products
# true_label: 57,Mushrooms
#
#
# item: Porc dorigine britannique élevé en plein air 80 Pommes Bramley rôties au miel 7 Pommes Bramley Miel Cannelle moulue Correcteur dacidité Acide ascorbique Blanc d_oeufs_ de poules élevées en plein air pasteurisés Pommes déshydratées Eau Miel Sucre Sel Sauge Épices moulues Noix de muscade Cannelle Clous de girofle Stabilisant E450 Poivre noir concassé Conservateur E223 _Sulfites_ Antioxydant Acide ascorbique Extrait de levure Saucisses embossés dans du boyau de porc
# true_label: 233,Meats
# true_label: 270,Prepared meats
# true_label: 271,Sausages
#
#
# item: Flat leaf parsley
# label: 263,herbs
# true_label: 30,Flat Parsley
# true_label: 31,Parsley
# true_label: 32,Herbs
#
#
# item: Water Tomato Purée 15 Tomatoes 14 Onions 12 Coriander Leaf 6 Sugar Rapseed Oil Ground Coriander Ground Cumin Ginger Purée Garlic Purée Salt Creamed Coconut Concentrated Lemon Juice Chilli Powder Acidity Regulators Citric Acid Acetic Acid Ground Cardamom Onion Purée Tumeric Ground Black Pepper Ground Ginger Ground Fenugreek Fenugreek Leaf Ground Nutmeg Paprika Ground Cinnamon Garlic Powder Stabiliser Xanthan Gum Cumin Seeds Ground Fennel Ground Cloves Black Onion Seeds
# true_label: 112,Sauces
# true_label: 283,Groceries
# true_label: 881,Curry pastes
# true_label: 882,Tikka curry paste
#
#
# item: Farine de _blé_ contient _gluten_ avec farine de _blé_ carbonate de calcium fer niacine thiamine sucre sirop de glucose partiellement inverti huile de palme gingembre moulu poudre à lever bicarbonate de soude E450 E503 sel émulsifiant lécithine de _soja_ arôme
# label: 41,Cookies
# true_label: 0,Snacks sucrés
# true_label: 2,Biscuits et gâteaux
# true_label: 22,Biscuits
#
#
# item: Sugar Strawberries Acidity Regulator Citric Acid E331 Gelling Agent Pectin  Prepared with 55g of fruit per 100g    Total sugar content 62g per 100g
# true_label: 602,strawberry jams
#
#
# item: INGREDIENTS  LAITUE VINAIGRETTE HUILE DE CANOLA EAU AIL JAUNE DOEUF CONGELE FROMAGE PARMESAN JUS DE CITRON CONCENTRE SEL PATE DANCHOIS ASSAISONNEMENTS GOMME XANTHANE FROMAGE PARMESAN CROUTONS FARINE FARINE DE BLE ENTIER HUILE DE PALME EAU GLUCOSEFRUCTOSE FARINE DE SEIGLE SEL GLUTEN DE BLE CARAMEL MELASSE OUALITE FANTAISIE POUDRE DE LACTOSERUM MALTODEXTRINE CARVI LEVURE VINAIGRE SUCRE POUDRE DAIL LEVAIN DE SEIGLE  PERSIL ACIDE ASCORBIQUE PHOSPHATE MONOCALCIQUE SULFATE DAMMONIUM SULFATE DE CALCIUM CITRON
# true_label: 266,Légumes-feuilles
#
#
# item: Carrot 34 Broccoli 33 Sweetcom 33
# true_label: 801,frozen vegetables
#
#
# item: COCOA MASS SUGAR COCOA BUTTER _SOY_ LECITHIN NATURAL VANILLA FLAVOR
# label: 152,Chocolates
# true_label: 694,chocolate bar
#
#
# item: ORGANIC APPLES ASCORBIC ACID CALCIUM CARBONATE TO MAINTAIN FRESHNESS AND COLOR
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 17,Fruits and vegetables based foods
# true_label: 189,Fruits based foods
# true_label: 319,Fruits
# true_label: 604,Apples
#
#
# item: Contient des _sulfites_
# label: 466,Boissons alcoolisées
# label: 529,Vins
# true_label: 241,Boissons
# true_label: 466,Boissons alcoolisées
# true_label: 529,Vins
# true_label: 530,Vins français
# true_label: 730,Vouvray
#
#
# item: Pâtisseries fourrées à la pulpe de pêche  farine de blé fourrage pêche 20 sirop de glucosefructose purée de pêche 50 sucre gélifiant  pectines correcteurs dacidité  acide citrique  citrates de sodium arômes conservateur  sorbate de potassium huile de colza œufs frais sucre sirop de glucosefructose stabilisant  glycérol poudres à lever  carbonates dammonium  carbonates de sodium  diphosphates blé sel lait écrémé en poudre émulsifiants  mono et diglycérides dacides gras arôme  exprimé sur le fourrage équivalent à 10 sur lensemble du produit Pâtisseries fourrées à la pulpe dabricot  farine de blé fourrage abricot 20 sirop de glucosefructose purée dabricot 50 sucre gélifiant  pectines correcteurs dacidité  acide citrique  citrates de sodium arômes conservateur  sorbate de potassium huile de colza œufs frais sucre sirop de glucosefructose stabilisant  glycérol poudres à lever  carbonates dammonium  carbonates de sodium  diphosphates blé sel lait écrémé en poudre émulsifiants  mono et diglycérides dacides gras arôme  exprimé sur le fourrage équivalent à 10 sur lensemble du produit Pâtisseries fourrées à la pulpe de fruits rouges  farine de blé fourrage fruits rouges 20 sirop de glucosefructose purée de fraise 178 sucre purée de framboise concentrée 5 équivalent à 212 de purée de framboise purée de cerise concentrée 3 équivalent à 11 de purée de cerise gélifiant  pectines correcteurs dacidité  acide citrique  citrates de sodium arôme conservateur  sorbate de potassium huile de colza œufs frais sucre sirop de glucosefructose stabilisant  glycérol poudres à lever  carbonates dammonium  carbonates de sodium  diphosphates blé sel lait écrémé en poudre émulsifiants  mono et diglycérides dacides gras arôme soit un équivalent de 50 de purée de fruits sur le fourrage équivalent à 10 sur lensemble du produit
# label: 8,Pâtisseries
# true_label: 3,Gâteaux
# true_label: 12,Goûters individuels
#
#
# item: Germes de haricot  Champignons 30   Carottes  Jeunes choux  Oignons
# true_label: 444,Poêlées
# true_label: 445,Mélanges de légumes frais
#
#
# item: lettuce
# true_label: 315,vegetable
#
#
# item: Cooked pasta 39 Tomatoes 21 water cooked ham 6 Roasted Chestnut Mushrooms 4 _Mature Cheddar cheese_ 4 contains Potato Starch _Mozzarella cheese_ 4 contains Potato Starch _Mascarpone Cheese_ 3 Tomato purée _Mozzarella Pearls_ 2 Onions Rapeseed oil extra virgin olive oil garlic puree Sugar  Cornflour  Salt Basil Olive oil Cracked Black Pepper Cooked Pasta contains Durum _Wheat_ Semolina  Water Cooked Ham contains Pork 92 Water  Curing Salt Salt preservative Sodium Nitrite  Sugar  Emulslflier E450 E451 E452  Antioxidant E301
# true_label: 61,Plats préparés
# true_label: 121,Plats préparés à réchauffer au micro-ondes
# true_label: 122,Plats à base de viande porcine
# true_label: 124,Plats préparés frais
#
#
# item: Pure water aloe vera juice aloe vera pulp water cane sugar calcium lactate citric acid malic acid sodium citrate sodium erythorbate gellan gum acesulfame potassium stevia white grape flavor
# label: 1104,Plant-based-beverages
# label: 1105,Aloe Vera Drinks
# true_label: 1104,Plant-based-beverages
# true_label: 1105,Aloe Vera Drinks
#
#
# item: Farine de _blé_ contient _Gluten_ avec _Farine_ de _blé_ Carbonate de calcium Fer Niacine Thiamine  Sucre  Huile de palme  Cacao maigre en poudre  Sirop de glucose  Dextrose  Amidon de _blé_ contient  _Gluten_  Poudre à lever  Bicarbonate de soude E503  Sel  Arôme
# true_label: 0,Snacks sucrés
# true_label: 2,Biscuits et gâteaux
# true_label: 22,Biscuits
# true_label: 478,Biscuits sablés
# true_label: 479,Bourbon Biscuits
#
#
# item: french wheat flour water yeast fermented wheat flour ascorbic acid
# true_label: 401,Breads
#
#
# item: Peas  Produced to EC Organic Regulations GBORG05 EU Agriculture
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 17,Fruits and vegetables based foods
# true_label: 18,Vegetables based foods
# true_label: 733,Frozen foods
# true_label: 788,Frozen plant-based foods
# true_label: 789,Frozen vegetables
#
#
# item: PURE FILTERED WATER SUGAR LEMON JUICE NATURAL FLAVORS
# true_label: 297,Sodas
# true_label: 328,Beverages
# true_label: 582,Carbonated drinks
# true_label: 583,Lemonades
#
#
# item: Cantaloupe
# true_label: 771,Cantaloupe
#
#
# item: Variety Driscolls Victoria
# true_label: 885,Blackberries
#
#
# item: cocoa mass sugar cocoa butter natural Bourbon vanilla bean
# true_label: 942,Dark Chocolate
#
#
# item: Flocons de riz et pétales de blé 83 Riz Sucre  _Blé_ concassé contient _Gluten_ _Gluten_ de _blé_ Germe de _blé_ contient _Gluten_ Sel Extrait de malt d_orge_ contient _Gluten_ Cannelle moulue Acide folique Vitamine B6 Vitamine B2 Vitamine B12 Vitamine B1 Fer Niacine Vitamine D Flocons de maïs 10 Gruau de maïs Sucre Sel Extrait de malt d_orge_ contient _Gluten_ Morceaux de pomme déshydratés 7
# label: 586,Céréales pour petit-déjeuner
# true_label: 44,Petit-déjeuners
# true_label: 74,Aliments et boissons à base de végétaux
# true_label: 75,Aliments d'origine végétale
# true_label: 433,Céréales et pommes de terre
# true_label: 542,Céréales et dérivés
# true_label: 586,Céréales pour petit-déjeuner
# true_label: 587,Flocons
# true_label: 588,Flocons de céréales
# true_label: 589,Mélanges de flocons de céréales
# true_label: 590,Corn-flakes
#
#
# item: White Beet Sugar 985 Anticaking Agent Tricalcium Phosphate
# true_label: 232,Sugar
# true_label: 239,Icing Sugar
#
#
# item: baby button mushrooms
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 17,Fruits and vegetables based foods
# true_label: 18,Vegetables based foods
# true_label: 19,Fresh foods
# true_label: 35,Fresh plant-based foods
# true_label: 56,Mushrooms and their products
# true_label: 57,Mushrooms
#
#
# item: Proteinmischung _Sojaprotein_ _Weizenprotein_ _Molkenprotein_ _Wheyprotein_ _Milchprotein_ _Hühnereiweiss_ Kakaopulver nur Sorte Schoko Aroma Pflanzenöl Süßungsmittel Natriumsaccharin und AcesulfamK
# label: 1043,Proteinpulver
# true_label: 1043,Proteinpulver
#
#
# item: Purified water aloe vera gel 20 fructose sugar calcium lactate natural mango flavor citric acid sodium citrate gellan gum beta carotene ascorbic acid vitamin c sucralose cochineal extract honey
# label: 1104,Plant-based-beverages
# label: 1105,Aloe Vera Drinks
# true_label: 1104,Plant-based-beverages
# true_label: 1105,Aloe Vera Drinks
#
#
# item: British Minced Beef Steak
# true_label: 992,Minced Beef Steak
#
#
# item: Water
# true_label: 328,Beverages
# true_label: 394,Non-sugared beverages
# true_label: 441,Waters
#
#
# item:
# true_label: 187,Breakfasts
# true_label: 188,Spreads
# true_label: 191,Sweet spreads
# true_label: 193,Jams
#
#
# item: Pâtes cuites 25 Eau  Semoule de blé dur contient _Gluten_  Eau  _Lait_ demiécrémé  Brocoli 9  Tomates 8  Crème britannique _Lait_  Fromages 6 Fromage blanc _Lait_  Fromage cheddar _Lait_  Fromage mozzarella _Lait_  Fromage cheddar affiné _Lait_  Fromage à pâte dure _Lait_  Épinards 5  Petits Pois 25  Oignons  Concentré de tomate  Farine de blé contient _Gluten_ avec Farine de blé Carbonate de calcium Fer Niacine Thiamine  Carottes  Huile dolive vierge extra  Huile de colza  _Céleri_  Fécule de maïs  Purée dail  Sel de mer  Sel  Sucre  Vinaigre balsamique  Basilic  Huile de tournesol  Tomates séchées  Vinaigre  Épices moulues Poivre blanc Poivre noir Piments  Curcuma  Vinaigre de vin blanc  Thym citron  Romarin_ Farine de _moutarde_ brune  Farine de _moutarde_ jaune  Origan déshydraté  Cosse  de _moutarde_  Graines de fenouil Romarin moulu  Arômes
# label: 121,Plats préparés à réchauffer au micro-ondes
# true_label: 61,Plats préparés
# true_label: 74,Aliments et boissons à base de végétaux
# true_label: 75,Aliments d'origine végétale
# true_label: 123,Frais
# true_label: 124,Plats préparés frais
# true_label: 499,Plats préparés d'origine végétale
#
#
# item: Sucre _Arachide_ pâte de cacao lait écrémé en poudre _lactose_ et protéine de _lait_ matières grasses végétales beurre de cacao _beurre_ concentré amidon sirop de glucose Iécithine de _soja_ gomme arabique colorant arôme sel huile végétale
# true_label: 836,Bonbons de chocolat
#
#
# item: Eau gazéifiée sucre colorant caramel E150d acidifiant  acide phosphorique arômes dont  extraits naturels de végétaux caféine
# true_label: 985,Sodas au cola
#
#
# item: Jus de pomme pressée pasteurisé  Purée de banane  Purée de pomme  Purée dei cassis 10  Puree de framboise 1096  Purée de baie dlaçaï  correcteur dacidité  Acide citrique   Antioxydant  Acide ascorbique iNFORMATlON Ce produit peut se idissocier naturellement INGREDIÈNTEN  Gepasteuriseerd geperst àppelsap  bananenpuree  làppelpuree  zwafte bessenpuree S  frambozenpuree 10  bessenpuree  zuufteregelaar titrcenzuur  antioxidant Èscorbinezuur INFORMATE Dit product kan van nature bezinken movennesGemiddelde waarden   ter 00ml EnergieEnergie 3ò6KJ87kcal  Matières grasses letten 19g dont acides gras saturés Waawan verzadigde vetzuren 10g  Guc desKoolhydraten 148g dont Sucreswaarvan suikers 94g  Fibres àmentairesNezels 06g  Protéines 23g  SelZout 005g 565 looml 2531 per 500ml 1251   Valeurs Nutritionnelles a Référence VRI Dagelijkse Referentielnnanne BEST BEFORE
# true_label: 281,en:beverages
#
#
# item: Framboise 50 sucre eau gélifiant  pectine
# true_label: 997,Coulis de framboise
#
#
# item: Organic mature cheddar
# true_label: 211,Dairies
# true_label: 212,Cheeses
#
#
# item: Cocoa Mass Sugar Fat Reduced Cocoa Powder Emulsifier _Soja_ Lecithin Dark Chocolate contains Cocoa Soiids 76 minimum
# true_label: 851,Dark Chocolates
#
#
# item: Pomme de terre  huile de tournesol  sucre  vinaigre balsamique déshydraté  sel de mer  vinaigre de malt dorge déshydraté  acidifiant  acide citrique acide tartrique  extrait de vin rouge
# true_label: 507,fr:Chips de pommes de terre à l'huile d'olive
# true_label: 508,fr:Chips au sel et vinaigre
#
#
# item: Spring Greens
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 17,Fruits and vegetables based foods
# true_label: 18,Vegetables based foods
# true_label: 19,Fresh foods
# true_label: 20,Fresh vegetables
# true_label: 100,Cabbage
#
#
# item: Farine de blé contient _Gluten_ avec Farine de blé Carbonate de calcium Fer Niacine Thiamine  Sucre  Raisins secs réhydratés 17 Ralslns Smyrne  Raisins  Raisins de Corinthe  Eau  Eau  Graisse de palme  Écorces dorange et de citron15  Huile de colza  _Gluten_ de blé déshydraté  Sirop de sucre inverti  Émulsifiants  E472c E47 E472e E435  Levure  Sel  Huile de palme  Épices moulues Cannelle  Coriandre  Cannelle de Chine Gélifiant  Agaragar  Arômes Amidon de blé contient _Gluten_
# true_label: 395,Brioches
# true_label: 396,Brioches au fruit
#
#
# item: Enriched flour wheat flour malted barley niacin reduced iron thiamine mononitrate riboflavin folic acid water yeast sugar soybean oil maltodextrin wheat gluten contains 2 or less of honey high fructose corn syrup crystalline fructose s
# label: 350,fr:Pains-Burgers
# true_label: 350,fr:Pains-Burgers
#
#
# item: Organic Tomatoes 60 Organic Tomato Juice Acidity Regulator Citric Acid
# true_label: 785,canned tomatoes
# true_label: 786,canned vegetables
#
#
# item: Water Sugar Tomato Pasta 10 Vinegar Glucose Fructose Syrup Cornflour Black Treacle Salt Colour Plain Caramel Dried Onions Smoke Flavouring Smoked Paprika Ground Black Pepper Preservative E202
# true_label: 679,Barbecue Sauce
#
#
# item: Miel de Sarrasin 100
# label: 44,Petit-déjeuners
# label: 45,Produits à tartiner
# label: 46,Produits à tartiner sucrés
# label: 47,Produits de la ruche
# label: 48,Produits d'élevages
# label: 49,Édulcorants
# label: 50,Miels
# true_label: 44,Petit-déjeuners
# true_label: 45,Produits à tartiner
# true_label: 46,Produits à tartiner sucrés
# true_label: 47,Produits de la ruche
# true_label: 48,Produits d'élevages
# true_label: 49,Édulcorants
# true_label: 50,Miels
#
#
# item: Flocons davoine 22 _gluten_  Pétales de blé malté grillés pétales de _blé_ _gluten_ extrait de malt d_orge_ _gluten_  Raisins Flame chiliens 16  Flocons dorge _gluten_  Raisins de Smyrne 10  Abricots déshydratés 8  Amandes effilées 3  Noisettes 3  Copeaux de bananes déshydratés 25  Farine de riz  Huile de tournesol  Huile de palme  Conservateur  E220 _sulfites_
# true_label: 44,Petit-déjeuners
# true_label: 74,Aliments et boissons à base de végétaux
# true_label: 75,Aliments d'origine végétale
# true_label: 433,Céréales et pommes de terre
# true_label: 542,Céréales et dérivés
# true_label: 586,Céréales pour petit-déjeuner
# true_label: 587,Flocons
# true_label: 588,Flocons de céréales
# true_label: 589,Mélanges de flocons de céréales
# true_label: 591,Mueslis
#
#
# item: Vin rouge sec Contient des _sulfites_
# true_label: 241,Boissons
# true_label: 466,Boissons alcoolisées
# true_label: 529,Vins
# true_label: 530,Vins français
# true_label: 910,Vins rouges
# true_label: 1036,Côtes du Rhône
# true_label: 1037,Côtes du Rhône Villages
#
#
# item: Rice and Wheatflakes Rice  Wheatflakes contain _Gluten_  Sugar  Wheat _Gluten_  Wheatgerm contains _Gluten_  Barley Malt Extract contains _Gluten_  Salt  Niacin  Iron  Vitamin B6  Riboflavin  Thiamin  Folic Acid  Vitamin D  Vitamin B12  FreezeDried Strawberry Slices and Pieces 3 Strawberries  Palm Oil  FreezeDried Sour Cherry Pieces 3
# true_label: 44,Petit-déjeuners
# true_label: 74,Aliments et boissons à base de végétaux
# true_label: 75,Aliments d'origine végétale
# true_label: 433,Céréales et pommes de terre
# true_label: 542,Céréales et dérivés
# true_label: 586,Céréales pour petit-déjeuner
# true_label: 587,Flocons
# true_label: 588,Flocons de céréales
#
#
# item: Graines de cardamome
# true_label: 74,Aliments et boissons à base de végétaux
# true_label: 75,Aliments d'origine végétale
# true_label: 110,Epicerie
# true_label: 355,Condiments
# true_label: 418,Epices
# true_label: 419,Cardamome
# true_label: 420,Graines de cardamome
#
#
# item: Venison 74 British Outdoor Bred Pork 12 Water  Red Onions 4 Gluten Free Crumb Rice Flour  Chickpea Flour  Comour  Salt  Dextrose  Sait  Pork Fat  Parsley  Thyme  Cracked Black Pepper  Red Chilli Peppers  Preservative E223 _Sulphites_  Antioxidant  E301
# true_label: 67,Viandes
# true_label: 68,Charcuteries
# true_label: 306,Saucisses
# true_label: 307,Chevreuil
#
#
# item: Sugar palm oil _hazelnuts_ cocoa skim _milk_ reduced minerals whey _milk_ lecithin as emulsifier _soja_ vanillin  an artificial flavor
# label: 732,Pâtes à tartiner aux noisettes et au cacao
# true_label: 44,Petit-déjeuners
# true_label: 45,Produits à tartiner
# true_label: 46,Produits à tartiner sucrés
# true_label: 732,Pâtes à tartiner aux noisettes et au cacao
# true_label: 947,Pâtes à tartiner
# true_label: 948,Pâtes à tartiner au chocolat
# true_label: 949,Pâtes à tartiner aux noisettes
#
#
# item: Strawberries liquid sugar sugar water sugar lemon juice concentrate pectin
# true_label: 635,Strawberry Preserves
#
#
# item: 0231rn
# true_label: 281,en:beverages
#
#
# item: Sucre sirop de maïs sirop de maïs a teneur élevée en fructose acide citrique arômes naturels et artificiels colorants rouge 40 bleu 1
# true_label: 40,Bonbons
#
#
# item: Homard _Crustacé_ 84 Fromage blanc _Lait_ Pointes dasperges 25 Huile de colza Crème _Lait_ Jus de citron Fécule de maïs Jaune d_œufs_ de poules élevées en plein air pasteurisés Sel Vinaigre Gélatine de _poisson_ Vinaigre de vin blanc Sucre Jus de citron concentré Graines de _moutarde_ noire
# true_label: 61,Plats préparés
# true_label: 91,Produits de la mer
# true_label: 123,Frais
# true_label: 124,Plats préparés frais
# true_label: 147,Crustacés
# true_label: 148,Homards
# true_label: 149,Plats à base de crustacés
#
#
# item: Cooked Chickpeas 37 Water Chickpeas Onion Rapeseed Oil Broad Beans 16 Breadcrumbs Fortified British Wheat Flour _Wheat_ Flour Calcium Carbonate Iron Niacin Thiamin Yeast Salt Coriander Parsley Garlic Purée Gram Flour Salt Coriander Powder Concentrated Lemon Juice Cumin Powder Baking Powder Fortified British Wheat Flour _Wheat_ Flour Calcium Carbonate Iron Thiamin Black Pepper
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 163,Meals
# true_label: 669,Falafel
# true_label: 815,Plant-based meals
#
#
# item: Coriander
# label: 32,Herbs
# true_label: 32,Herbs
# true_label: 795,Fresh Herbs
#
#
# item: Strawberries Sugar GlucoseFructose syrup Water Gelling Agent Pectin Acidity Regulators Citric Acid Sodium Citrate Preservative Potassium Sorbate
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 17,Fruits and vegetables based foods
# true_label: 187,Breakfasts
# true_label: 188,Spreads
# true_label: 189,Fruits based foods
# true_label: 190,Plant-based spreads
# true_label: 191,Sweet spreads
# true_label: 192,Fruit preserves
# true_label: 193,Jams
# true_label: 194,Fruit jams
# true_label: 195,Berry jams
# true_label: 196,Strawberry jams
#
#
# item: Farine de _blé_ contient _Gluten_ avec Farine de _blé_ Carbonate de calcium Fer Niacine Thiamine  Eau  _Œufs_ de poules élevées en plein air pasteurisés  _Beurre_ _lait_ 5  Sucre  _Lait_ en poudre entier  Huile de colza  Fibres de _blé_ contient _Gluten_  Sirop de sucre inverti  Levure Levure  Levure enrichie en vitamine D  Émulsifiant  E472e E471  Graisse de palme
# true_label: 681,Pains à hamburger
# true_label: 682,Pains Burger
# true_label: 683,Buns
#
#
# item: watercress 40 Spinash 40 Rocket 20
# true_label: 915,salads
#
#
# item: Farine de blé contient _Gluten_ avec Farine de blé Carbonate de calcium Fer Niacine Thiamine  Viande de bœuf cuite 24  Eau  Huile de palme  Saindoux de porc  Oignons  Huile de colza  Bouillon de bœuf rôti Eau  Os de bœuf rôti  Viande de bœuf  Extrait de levure  Sel  Fécule de maïs  _Œufs_ de poules élevées en plein air pasteurisés  Concentré de tomate  Sirop de sucre noir  Extrait de levure  Sel  Sucre caramélisé  Graisse de bœuf  Beurre _Lait_  Poivre noir moulu  Thym moulu
# true_label: 124,Plats préparés frais
# true_label: 176,Plats à base de viande bovine
# true_label: 177,Tourtes
#
#
# item: Flocons d_avoine_ 64  Graines de lin doré moulues 9  Jus de pomme concentré  Graines de citrouille  5  Graines de tournesol 5  Miel  Huile de colza
# true_label: 44,Petit-déjeuners
# true_label: 74,Aliments et boissons à base de végétaux
# true_label: 75,Aliments d'origine végétale
# true_label: 433,Céréales et pommes de terre
# true_label: 542,Céréales et dérivés
# true_label: 586,Céréales pour petit-déjeuner
# true_label: 587,Flocons
# true_label: 588,Flocons de céréales
# true_label: 589,Mélanges de flocons de céréales
# true_label: 591,Mueslis
# true_label: 613,Mueslis croustillants
# true_label: 614,Céréales au miel
#
#
# item: Raisins 28 Sugar Wheat Flour Cider 12 contains Preservative Soddium Metabisulphite Sultanas 10 Palm Fat Water Humectant Glycerol Candied Citrus Peel Glucose Syrup Orange Peel Sugar Lemon Peel Acid Citric Acid Sherry 2 Orange and Lemon Peel Rum 1 Molasses Mixed Spice Coriander Cinnamon Clove Fennel Ginger Nutmeg Cardamom Salt Yeast Orange Oil
# label: 1,Desserts
# label: 7,Cakes
# label: 151,Sugary snacks
# label: 169,Biscuits and cakes
# label: 170,Christmas Puddings
# label: 171,Puddings
# true_label: 150,Christmas Pudding
#
#
# item: Apples variety Cripps Pink
# true_label: 15,Plant-based foods and beverages
# true_label: 16,Plant-based foods
# true_label: 17,Fruits and vegetables based foods
# true_label: 189,Fruits based foods
# true_label: 260,Fresh Fruits
# true_label: 319,Fruits
# true_label: 604,Apples
#
#
# item: red ripened jalapeno peppers distilled vinegar salt
# label: 112,Sauces
# true_label: 112,Sauces
# true_label: 283,Groceries
# true_label: 321,Hot sauces
